# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('traffic.csv')

# %%
df.head()
# Out:
#    event        date       country      city  \
# 0  click  2021-08-21  Saudi Arabia    Jeddah
# 1  click  2021-08-21  Saudi Arabia    Jeddah
# 2  click  2021-08-21         India  Ludhiana
# 3  click  2021-08-21        France   Unknown
# 4  click  2021-08-21      Maldives      Malé
#
#                               artist          album          track  \
# 0                             Tesher    Jalebi Baby    Jalebi Baby
# 1                             Tesher    Jalebi Baby    Jalebi Baby
# 2                      Reyanna Maria      So Pretty      So Pretty
# 3  Simone & Simaria, Sebastian Yatra  No Llores Más  No Llores Más
# 4                             Tesher    Jalebi Baby    Jalebi Baby
#
#            isrc                                linkid
# 0  QZNWQ2070741  2d896d31-97b6-4869-967b-1c5fb9cd4bb8
# 1  QZNWQ2070741  2d896d31-97b6-4869-967b-1c5fb9cd4bb8
# 2  USUM72100871  23199824-9cf5-4b98-942a-34965c3b0cc2
# 3  BRUM72003904  35573248-4e49-47c7-af80-08a960fa74cd
# 4  QZNWQ2070741  2d896d31-97b6-4869-967b-1c5fb9cd4bb8

# %%
df.describe(include='all')
# Out:
#            event        date       country    city  artist        album  \
# count     226278      226278        226267  226267  226241       226273
# unique         3           7           211   11993    2419         3254
# top     pageview  2021-08-19  Saudi Arabia  Jeddah  Tesher  Jalebi Baby
# freq      142015       35361         47334   22791   40841        40841
#
#               track          isrc                                linkid
# count        226273        219157                                226278
# unique         3562           709                                  3839
# top     Jalebi Baby  QZNWQ2070741  2d896d31-97b6-4869-967b-1c5fb9cd4bb8
# freq          40841         40841                                 40841

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 226278 entries, 0 to 226277
# Data columns (total 9 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   event    226278 non-null  object
#  1   date     226278 non-null  object
#  2   country  226267 non-null  object
#  3   city     226267 non-null  object
#  4   artist   226241 non-null  object
#  5   album    226273 non-null  object
#  6   track    226273 non-null  object
#  7   isrc     219157 non-null  object
#  8   linkid   226278 non-null  object
# dtypes: object(9)
# memory usage: 15.5+ MB

# %%
df.dtypes
# Out:
# event      object
# date       object
# country    object
# city       object
# artist     object
# album      object
# track      object
# isrc       object
# linkid     object
# dtype: object

# %%
df[df.isna().any(axis=1)]
# Out:
#            event        date        country          city  \
# 278        click  2021-08-20  United States  Philadelphia
# 301        click  2021-08-20  United States   Front Royal
# 302        click  2021-08-20  United States    Boca Raton
# 305        click  2021-08-20  United States    Stillwater
# 312        click  2021-08-20  United States   San Antonio
# ...          ...         ...            ...           ...
# 226092  pageview  2021-08-19  United States       Lansing
# 226166  pageview  2021-08-19  United States   San Antonio
# 226178  pageview  2021-08-20  United States    Snellville
# 226181  pageview  2021-08-20  United States  Whitley City
# 226186  pageview  2021-08-20  United States       Atlanta
#
#                             artist  \
# 278     YoungBoy Never Broke Again
# 301                      YNW Melly
# 302                Little Big Town
# 305              Lofi Fruits Music
# 312                     Sayyhuncho
# ...                            ...
# 226092                    KA$HDAMI
# 226166                  Gucci Mane
# 226178               Sammy Kershaw
# 226181                      Kiiara
# 226186                        Maze
#
#                                                     album  \
# 278                                                   Top
# 301                                          We All Shine
# 302     Restoration: The Songs of Elton John and Berni...
# 305                                       Steven Universe
# 312                                          None Regular
# ...                                                   ...
# 226092                                           epiphany
# 226166                                  Everybody Looking
# 226178                                      Haunted Heart
# 226181                                     low kii savage
# 226186                    Golden Time Of Day (Remastered)
#
#                                          track isrc  \
# 278                                       Boom  NaN
# 301     Mixed Personalities (feat. Kanye West)  NaN
# 302                                 Rocket Man  NaN
# 305                            Steven Universe  NaN
# 312                               None Regular  NaN
# ...                                        ...  ...
# 226092                           ILY/Sincerely  NaN
# 226166                        No Sleep - Intro  NaN
# 226178          She Don't Know She's Beautiful  NaN
# 226181                                    Gold  NaN
# 226186                 I Need You - Remastered  NaN
#
#                                       linkid
# 278     5f86ad60-5c3a-5996-8c4b-b32ccba46e6f
# 301     457538c1-61e2-5f7b-914c-43e85177ec3a
# 302     c25059fe-2763-5e66-9cce-84e9766d1c4b
# 305     eb28ae21-888f-5440-bd79-05a631f5dccd
# 312     a396942a-04b5-5cfa-9121-7a082081b489
# ...                                      ...
# 226092  83691506-2318-5a15-a7c8-602f055fed59
# 226166  9e186531-3b42-566e-a30b-003d56e9530f
# 226178  2a20c79c-7578-5247-878b-a6b71fba3769
# 226181  ac33e71b-209d-5503-a276-14ca46372a81
# 226186  b8ba0599-0599-586d-88e0-0bcc03bb69c8
#
# [7129 rows x 9 columns]
